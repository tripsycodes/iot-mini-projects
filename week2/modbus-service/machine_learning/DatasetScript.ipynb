# %%
! pip install soilgrids
# Out:
# Requirement already satisfied: soilgrids in /usr/local/lib/python3.12/dist-packages (0.1.5)
# Requirement already satisfied: bmipy in /usr/local/lib/python3.12/dist-packages (from soilgrids) (2.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from soilgrids) (8.3.1)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.12/dist-packages (from soilgrids) (1.7.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from soilgrids) (2.0.2)
# Requirement already satisfied: owslib in /usr/local/lib/python3.12/dist-packages (from soilgrids) (0.35.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from soilgrids) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from soilgrids) (2.32.4)
# Requirement already satisfied: rioxarray in /usr/local/lib/python3.12/dist-packages (from soilgrids) (0.21.0)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from soilgrids) (2025.11.0)
# Requirement already satisfied: black in /usr/local/lib/python3.12/dist-packages (from bmipy->soilgrids) (26.1.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from bmipy->soilgrids) (3.1.6)
# Requirement already satisfied: cftime in /usr/local/lib/python3.12/dist-packages (from netcdf4->soilgrids) (1.6.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netcdf4->soilgrids) (2026.1.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from owslib->soilgrids) (6.0.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from owslib->soilgrids) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->soilgrids) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->soilgrids) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->soilgrids) (2.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from rioxarray->soilgrids) (26.0)
# Requirement already satisfied: rasterio>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from rioxarray->soilgrids) (1.5.0)
# Requirement already satisfied: pyproj>=3.3 in /usr/local/lib/python3.12/dist-packages (from rioxarray->soilgrids) (3.7.2)
# Requirement already satisfied: pandas>=2.2 in /usr/local/lib/python3.12/dist-packages (from xarray->soilgrids) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray->soilgrids) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray->soilgrids) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->owslib->soilgrids) (1.17.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.4.3->rioxarray->soilgrids) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.4.3->rioxarray->soilgrids) (25.4.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.4.3->rioxarray->soilgrids) (0.7.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.4.3->rioxarray->soilgrids) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from black->bmipy->soilgrids) (1.1.0)
# Requirement already satisfied: pathspec>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from black->bmipy->soilgrids) (1.0.4)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.12/dist-packages (from black->bmipy->soilgrids) (4.5.1)
# Requirement already satisfied: pytokens>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from black->bmipy->soilgrids) (0.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->bmipy->soilgrids) (3.0.3)

# %%
from soilgrids import SoilGrids

soil_grids = SoilGrids()

# India bounding box
extent = {
    "west": 68,
    "south": 8,
    "east": 98,
    "north": 36
}

# Required SoilGrids services
layers = [
    "phh2o",   # pH
    "cec",     # cation exchange capacity
    "ocd",     # organic carbon density
    "bdod",    # bulk density
    "sand",    # sand %
    "silt",    # silt %
    "clay",    # clay %
    #"awc"      # available water capacity
]

depth = "0-5cm"

for layer in layers:

    coverage = f"{layer}_{depth}_mean"
    output_file = f"india_{coverage}.tif"

    print(f"Downloading {coverage} ...")

    soil_grids.get_coverage_data(
        service_id=layer,
        coverage_id=coverage,
        west=extent["west"],
        south=extent["south"],
        east=extent["east"],
        north=extent["north"],
        crs="urn:ogc:def:crs:EPSG::4326",
        width=2000,
        height=2000,
        output=output_file
    )

print("All layers downloaded.")
# Out:
# Downloading phh2o_0-5cm_mean ...
# Downloading cec_0-5cm_mean ...
# Downloading ocd_0-5cm_mean ...
# Downloading bdod_0-5cm_mean ...
# Downloading sand_0-5cm_mean ...
# Downloading silt_0-5cm_mean ...
# Downloading clay_0-5cm_mean ...
# All layers downloaded.

# %%
import rasterio
import numpy as np
import pandas as pd

# Files downloaded earlier
files = {
    "pH": "india_phh2o_0-5cm_mean.tif",
    #"moisture": "india_awc_0-5cm_mean.tif",
    "conductivity_proxy": "india_cec_0-5cm_mean.tif",
    "salinity_proxy": "india_ocd_0-5cm_mean.tif",
    "sand": "india_sand_0-5cm_mean.tif",
    "silt": "india_silt_0-5cm_mean.tif",
    "clay": "india_clay_0-5cm_mean.tif",
    "ocd" : "india_ocd_0-5cm_mean.tif"
}

arrays = {}
transform = None

# Read rasters
for key, path in files.items():
    with rasterio.open(path) as src:
        arrays[key] = src.read(1)
        transform = src.transform

height, width = arrays["pH"].shape

# Create coordinate grid
rows, cols = np.meshgrid(np.arange(height), np.arange(width), indexing='ij')
xs, ys = rasterio.transform.xy(transform, rows, cols)

data = {
    "lat": np.array(ys).flatten(),
    "lon": np.array(xs).flatten()
}

# Add soil features
for key in arrays:
    data[key] = arrays[key].flatten()

df = pd.DataFrame(data)

# Remove invalid pixels
df = df.replace(-32768, np.nan).dropna()

# %%
df["tds_proxy"] = (
    df["conductivity_proxy"] * 0.6 +
    df["clay"] * 0.2 +
    df["salinity_proxy"] * 0.2
)

# %%
df["moisture_proxy"] = (
    0.5 * df["clay"] +
    0.3 * df["ocd"] -
    0.2 * df["sand"]
)

# %%
df.rename(columns={'tds_proxy': 'tds',
                   'conductivity_proxy': 'EC',
                   'salinity_proxy': 'salinity',
                   'moisture_proxy' : 'moisture',
                   'ocd' : 'OC'}, inplace=True)   #matching the sensor coulmns
df.drop(columns = ['sand', 'silt', 'clay', 'lat', 'lon'], inplace = True) #no longer required

# %%
print(df.head())
print(df.shape)
# Out:
#      pH     EC  salinity     OC    tds  moisture
# 0  77.0  220.0     243.0  243.0  241.0     165.3
# 1  77.0  220.0     218.0  218.0  239.2     168.4
# 2  77.0  218.0     218.0  218.0  236.0     162.8
# 3  77.0  224.0     260.0  260.0  247.0     170.7
# 4  77.0  217.0     264.0  264.0  243.8     173.0
# (2612234, 6)

# %%
df.to_csv('soil_dataset_final.csv', index=False)
